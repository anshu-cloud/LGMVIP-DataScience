# %% [markdown]
# **Lets Grow More**
#
#
#
# *   Author: Anshu Sharma
# *   task2: Decision Tree Classifier(Intermediate)

# %%
# importing all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
# loading dataset and viewing first and last rows
data = pd.read_csv("/content/Iris.csv")
data
df = pd.DataFrame(data)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [5 rows x 6 columns]

# %%
# dropping Id column
df.drop(columns='Id', axis=1,inplace = True)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# visualising classes of dataset
df.groupby(['Species'])['SepalLengthCm'].count().plot.bar()
plt.xlabel('Category')
plt.ylabel('Number of')
plt.show()

# %%
#depict corr between features
sb.heatmap(df.corr(),annot=True,cmap='cubehelix',center =0,linewidths=1.9)

# %%
sb.pairplot(df)

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# # Splitting the features and target (x and y respectively)

# %%
x= df.drop(columns='Species',axis =1)
y= df['Species']
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
from sklearn.model_selection import train_test_split

# %%
# splitting all data for training and testing
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=3)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %% [markdown]
# # Building Model

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()

# %%
dtree= dtree.fit(x_train,y_train)

print('Decesion Tree Model is Created')
# Out:
# Decesion Tree Model is Created

# %%
from sklearn import tree
plt.figure(figsize=(20,10))
tree.plot_tree(dtree,filled=True)
plt.show()

# %%
# checking acuuracy while training
from sklearn.model_selection import cross_val_score
cv_dt = cross_val_score(dtree, x_train, y_train, cv = 5, scoring = 'accuracy').mean()
print('For Decision Trees Classifier :', round(cv_dt,3))
# Out:
# For Decision Trees Classifier : 0.943

# %%
# Prediction using Model
y_pred = dtree.predict(x_test)
dfa = pd.DataFrame(y_pred)
dfa.head()
# Out:
#              0
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
y_test.head()
# Out:
# 47    Iris-setosa
# 3     Iris-setosa
# 31    Iris-setosa
# 25    Iris-setosa
# 15    Iris-setosa
# Name: Species, dtype: object

# %%
# checking final accuracy on test set
from sklearn.metrics import accuracy_score



str(round(accuracy_score(y_test, y_pred,  normalize=True, sample_weight=None) ))
# Out:
# '1'

# %% [markdown]
# **Conclusion:**
#
#
#
# *   Our model is giving 100% accuracy as its a small dataset.
# *   So,we created Decsion Tree Classifier and also visualised it.
# *   It will be able to predict for future data.
